# %%
import streamlit as st
import numpy as np
import rebrick

from PIL import Image
from io import BytesIO
import IPython.display as display

import rebrick_utils
# Out:
# 2024-09-05 16:45:05.205 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-09-05 16:45:05.207 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-09-05 16:45:05.209 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-09-05 16:45:05.211 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-09-05 16:45:05.213 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-09-05 16:45:05.214 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
# Initialize the Rebrickable API with your API key
client = rebrick.Rebrick(api_key=st.secrets["apit"])

# %%
parts = [3001]
colors = [0]

# %%
def find_sets_containing_parts(part_ids, part_colors):
    
    for part_id, part_color in zip(part_ids, part_colors):
    
        sets_with_part = client.get_part_color_sets(part_id, part_color)
        sets_ids = [set.collection_id for set in sets_with_part]        
        print(sets_ids)

# %%
sets_with_part = client.get_part_color_sets(3001, 1)

# %%
client.get_element_ids(3002, 2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client.get_element_ids(3002, 2)
#
# File ~/miniconda3/envs/pab/lib/python3.11/site-packages/rebrick/rebrick.py:270, in Rebrick.get_element_ids(self, part_id, color_id)
#     268 # send request
#     269 try:
# --> 270     response = lego.get_part_color(
#     271         part_id = part_id,
#     272         color_id = color_id,
#     273         api_key = self._api_key)
#     275 except urllib.error.HTTPError as e:
#     276     self._on_error(e)
#
# File ~/miniconda3/envs/pab/lib/python3.11/site-packages/rebrick/api_lego.py:512, in get_part_color(part_id, color_id, api_key)
#     508 parameters = {'key': api_key}
#     510 path = config.API_LEGO_URL + "parts/%s/colors/%s/" % (part_id, color_id)
# --> 512 return request(path, parameters)
#
# ...

# %%
img_data = client.get_element_image(4109674)

image = Image.open(BytesIO(img_data))

# Display the image
display.display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x192>

# %%
import local_data_utils

local_data_utils.find_sets_single_part(3001, 1)
# Out:
# 2024-09-05 16:42:38.749 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-09-05 16:42:38.779
# ...
#   command:
#
#     streamlit run /home/jucordero/miniconda3/envs/pab/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-09-05 16:42:38.781 No runtime found, using MemoryCacheStorageManager
# /home/jucordero/Documents/Personal/Lego/set_finder_streamlit_app/local_data_utils.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inv = set_inventory_id[inv_mask]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/pab/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# ...
